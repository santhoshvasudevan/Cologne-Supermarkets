# %% [markdown]
# # Battle of Neighbourhoods

# %% [markdown]
# ##

# %% [markdown]
# ## Part 1 - Web Scraping and Prepare DataFrame

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
wikipage = requests.get(url).text
soup = BeautifulSoup(wikipage,'lxml')
table = soup.find('table')

# %%
PCodes,boros,neighs = [],[],[]
for row in table.find_all('tr'):
    cols = row.find_all('td')
    for col in cols:
        # Assuming the text data of in the cell will have necessary information as required
        info = col.get_text().strip()
        if 'not assigned' not in info.lower(): # Assuming if the Postal Code has not been assigned, ignore the data
            PCodes.append(info[:3])
            i = info.find('(')
            boros.append(info[3:i])
            neighs.append(info[i+1:-1].replace('/',','))
        
datadict = {'PostalCode':PCodes,'Borough':boros,'Neighbourhood':neighs}
toronto_df = pd.DataFrame()
toronto_df = toronto_df.from_dict(datadict)
toronto_df.head(10)
# Out:
#   PostalCode           Borough                      Neighbourhood
# 0        M3A        North York                          Parkwoods
# 1        M4A        North York                   Victoria Village
# 2        M5A  Downtown Toronto         Regent Park , Harbourfront
# 3        M6A        North York  Lawrence Manor , Lawrence Heights
# 4        M7A      Queen's Park      Ontario Provincial Government
# 5        M9A         Etobicoke                   Islington Avenue
# 6        M1B       Scarborough                    Malvern , Rouge
# 7        M3B        North York                     Don Mills)Nort
# 8        M4B         East York   Parkview Hill , Woodbine Gardens
# 9        M5B  Downtown Toronto           Garden District, Ryerson

# %%
toronto_df.shape
# Out:
# (103, 3)

# %% [markdown]
# #

# %% [markdown]
# # Part 2 - Getting the Latitude and Logitude Data

# %% [markdown]
# #

# %%
# Using CSV file as below code does not take a finite time.
'''
import geocoder # import geocoder

def get_coordinates(postal_code):
    
    # initialize your variable to None
    lat_lng_coords = None

    # loop until you get the coordinates
    while(lat_lng_coords is None):
      g = geocoder.google('{}, Toronto, Ontario'.format(postal_code))
      lat_lng_coords = g.latlng

    return lat_lng_coords
    
latitude = lat_lng_coords[0]
longitude = lat_lng_coords[1]

toronto_df['Lats'] = toronto_df.apply(lambda x: get_coordinates(x['PostalCode']),axis=1)
toronto_df
'''
# Out:
# "\nimport geocoder # import geocoder\n\ndef get_coordinates(postal_code):\n    \n    # initialize your variable to None\n    lat_lng_coords = None\n\n    # loop until you get the coordinates\n    while(lat_lng_coords is None):\n      g = geocoder.google('{}, Toronto, Ontario'.format(postal_code))\n      lat_lng_coords = g.latlng\n\n    return lat_lng_coords\n    \nlatitude = lat_lng_coords[0]\nlongitude = lat_lng_coords[1]\n\ntoronto_df['Lats'] = toronto_df.apply(lambda x: get_coordinates(x['PostalCode']),axis=1)\ntoronto_df\n"

# %%
latlong = pd.read_csv('Geospatial_Coordinates.csv')
toronto_df = pd.merge(toronto_df,latlong,left_on='PostalCode',right_on='Postal Code')
toronto_df.drop('Postal Code',axis=1,inplace=True)

# %%
toronto_df.head()
# Out:
#   PostalCode           Borough                      Neighbourhood   Latitude  \
# 0        M3A        North York                          Parkwoods  43.753259
# 1        M4A        North York                   Victoria Village  43.725882
# 2        M5A  Downtown Toronto         Regent Park , Harbourfront  43.654260
# 3        M6A        North York  Lawrence Manor , Lawrence Heights  43.718518
# 4        M7A      Queen's Park      Ontario Provincial Government  43.662301
#
#    Longitude
# 0 -79.329656
# 1 -79.315572
# 2 -79.360636
# 3 -79.464763
# 4 -79.389494

# %%
toronto_df.isnull().values.any()
# Out:
# False

# %%
toronto_df.shape
# Out:
# (103, 5)

# %%
toronto_df['Borough'].unique()
# Out:
# array(['North York', 'Downtown Toronto', "Queen's Park", 'Etobicoke',
#        'Scarborough', 'East York', 'York', 'East Toronto', 'West Toronto',
#        'East YorkEast Toronto', 'Central Toronto',
#        'MississaugaCanada Post Gateway Processing Centre',
#        'Downtown TorontoStn A PO Boxes25 The Esplanade',
#        'EtobicokeNorthwest',
#        'East TorontoBusiness reply mail Processing Centre969 Eastern'],
#       dtype=object)

# %% [markdown]
# #

# %% [markdown]
# # Part 3 Explore and Cluster Neighbourhoods in Toronto

# %% [markdown]
# #

# %%
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

from pandas.io.json import json_normalize

import numpy as np

# import k-means from clustering stage
from sklearn.cluster import KMeans

import folium # map rendering library

# %%
print('This dataframe has {} boroughs and {} neighborhoods.'.format(
        len(toronto_df['Borough'].unique()),
        toronto_df.shape[0]
    )
)
# Out:
# This dataframe has 15 boroughs and 103 neighborhoods.

# %% [markdown]
# ### For Convinience reason im taking the top 11 Boroughs of Toronto and will continue processing with the data

# %%
filt_boro = list(toronto_df['Borough'].unique())[:11]
filt_boro
# Out:
# ['North York',
#  'Downtown Toronto',
#  "Queen's Park",
#  'Etobicoke',
#  'Scarborough',
#  'East York',
#  'York',
#  'East Toronto',
#  'West Toronto',
#  'East YorkEast Toronto',
#  'Central Toronto']

# %%
new_toronto_df = toronto_df[toronto_df['Borough'].isin(filt_boro)]
new_toronto_df
# Out:
#     PostalCode           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 3          M6A        North York
# 4          M7A      Queen's Park
# ..         ...               ...
# 97         M5X  Downtown Toronto
# 98         M8X         Etobicoke
# 99         M4Y  Downtown Toronto
# 101        M8Y         Etobicoke
# 102        M8Z         Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                            Parkwoods  43.753259 -79.329656
# 1                                     Victoria Village  43.725882 -79.315572
# 2                           Regent Park , Harbourfront  43.654260 -79.360636
# 3                    Lawrence Manor , Lawrence Heights  43.718518 -79.464763
# 4                        Ontario Provincial Government  43.662301 -79.389494
# ..                                                 ...        ...        ...
# 97             First Canadian Place , Underground city  43.648429 -79.382280
# 98     The Kingsway , Montgomery Road , Old Mill North  43.653654 -79.506944
# 99                                Church and Wellesley  43.665860 -79.383160
# 101  Old Mill South , King's Mill Park , Sunnylea ,...  43.636258 -79.498509
# 102  Mimico NW , The Queensway West , South of Bloo...  43.628841 -79.520999
#
# [99 rows x 5 columns]

# %%
new_toronto_df.shape
# Out:
# (99, 5)

# %% [markdown]
# ## Visualizing Downtown Toronto

# %%
downtown_df = new_toronto_df[new_toronto_df['Borough']=='Downtown Toronto'].reset_index(drop=True)
downtown_df
# Out:
#    PostalCode           Borough  \
# 0         M5A  Downtown Toronto
# 1         M5B  Downtown Toronto
# 2         M5C  Downtown Toronto
# 3         M5E  Downtown Toronto
# 4         M5G  Downtown Toronto
# 5         M6G  Downtown Toronto
# 6         M5H  Downtown Toronto
# 7         M5J  Downtown Toronto
# 8         M5K  Downtown Toronto
# 9         M5L  Downtown Toronto
# 10        M5S  Downtown Toronto
# 11        M5T  Downtown Toronto
# 12        M5V  Downtown Toronto
# 13        M4W  Downtown Toronto
# 14        M4X  Downtown Toronto
# 15        M5X  Downtown Toronto
# 16        M4Y  Downtown Toronto
#
#                                         Neighbourhood   Latitude  Longitude
# 0                          Regent Park , Harbourfront  43.654260 -79.360636
# 1                            Garden District, Ryerson  43.657162 -79.378937
# 2                                      St. James Town  43.651494 -79.375418
# 3                                         Berczy Park  43.644771 -79.373306
# 4                                  Central Bay Street  43.657952 -79.387383
# 5                                            Christie  43.669542 -79.422564
# 6                          Richmond , Adelaide , King  43.650571 -79.384568
# 7   Harbourfront East , Union Station , Toronto Is...  43.640816 -79.381752
# 8           Toronto Dominion Centre , Design Exchange  43.647177 -79.381576
# 9                     Commerce Court , Victoria Hotel  43.648198 -79.379817
# 10                    University of Toronto , Harbord  43.662696 -79.400049
# 11        Kensington Market , Chinatown , Grange Park  43.653206 -79.400049
# 12  CN Tower , King and Spadina , Railway Lands , ...  43.628947 -79.394420
# 13                                           Rosedale  43.679563 -79.377529
# 14                       St. James Town , Cabbagetown  43.667967 -79.367675
# 15            First Canadian Place , Underground city  43.648429 -79.382280
# 16                               Church and Wellesley  43.665860 -79.383160

# %%
address = "Downtown Toronto, Toronto"

geolocator = Nominatim(user_agent="toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print("The geograpical coordinate of {} are {}, {}".format(address,latitude, longitude))
# Out:
# The geograpical coordinate of Downtown Toronto, Toronto are 43.6541737, -79.38081164513409

# %%
# create map of downtown using latitude and longitude values
map_downtown = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(downtown_df['Latitude'], downtown_df['Longitude'], downtown_df['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_downtown)  
map_downtown
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_f23ffc7937e844888ca6ac5f026230d7%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_f23ffc7937e844888ca6ac5f026230d7%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_f23ffc7937e844888ca6ac5f026230d7%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_f23ffc7937e844888ca6ac5f026230d7%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B43.6541737%2C-79.38081164513409%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20% ...

# %% [markdown]
# ### Foursquare Credentials

# %%
CLIENT_ID = 'QH1IBX41PG0PBDOCVGOQNLQXJA52KXGEXJLK10YET1YMH5GM' # your Foursquare ID
CLIENT_SECRET = 'NM5A2OJVLPFYV02UIBKUCH2F5FLYQBJESG2NCRBJ3QIOXTEQ' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

# %% [markdown]
# ### Will explore first Neighbourhood of Toronto : Downtown

# %%
neighbourhood_name = downtown_df.loc[0,'Neighbourhood']
neighbourhood_lat = downtown_df.loc[0,'Latitude']
neighbourhood_long = downtown_df.loc[0,'Longitude']

# type your answer here
radius = 500 # define radius
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighbourhood_lat, 
    neighbourhood_long, 
    radius, 
    LIMIT)
url # display URL

results = requests.get(url).json()

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']
    
    
venues = results['response']['groups'][0]['items']
    
nearby_venues = pd.json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
#                      name           categories        lat        lng
# 0           Tandem Coffee          Coffee Shop  43.653559 -79.361809
# 1        Roselle Desserts               Bakery  43.653447 -79.362017
# 2  Cooper Koo Family YMCA  Distribution Center  43.653249 -79.358008
# 3          Impact Kitchen           Restaurant  43.656369 -79.356980
# 4     Body Blitz Spa East                  Spa  43.654735 -79.359874

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 45 venues were returned by Foursquare.

# %% [markdown]
# ### Explore all filtered neighbourhoods of Toronto

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

toronto_venues = getNearbyVenues(names=downtown_df['Neighbourhood'],latitudes=downtown_df['Latitude'],
                                      longitudes = downtown_df['Longitude'])
# Out:
# Regent Park , Harbourfront
# Garden District, Ryerson
# St. James Town
# Berczy Park
# Central Bay Street
# Christie
# Richmond , Adelaide , King
# Harbourfront East , Union Station , Toronto Islands
# Toronto Dominion Centre , Design Exchange
# Commerce Court , Victoria Hotel
# University of Toronto , Harbord
# Kensington Market , Chinatown , Grange Park
# CN Tower , King and Spadina , Railway Lands , Harbourfront West , Bathurst Quay , South Niagara , Island airport
# Rosedale
# St. James Town , Cabbagetown
# First Canadian Place , Underground city
# Church and Wellesley

# %%
print(toronto_venues.shape)
toronto_venues.head()
# Out:
# (1090, 7)
#                  Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Regent Park , Harbourfront               43.65426              -79.360636
# 1  Regent Park , Harbourfront               43.65426              -79.360636
# 2  Regent Park , Harbourfront               43.65426              -79.360636
# 3  Regent Park , Harbourfront               43.65426              -79.360636
# 4  Regent Park , Harbourfront               43.65426              -79.360636
#
#                     Venue  Venue Latitude  Venue Longitude  \
# 0           Tandem Coffee       43.653559       -79.361809
# 1        Roselle Desserts       43.653447       -79.362017
# 2  Cooper Koo Family YMCA       43.653249       -79.358008
# 3          Impact Kitchen       43.656369       -79.356980
# 4     Body Blitz Spa East       43.654735       -79.359874
#
#         Venue Category
# 0          Coffee Shop
# 1               Bakery
# 2  Distribution Center
# 3           Restaurant
# 4                  Spa

# %%
toronto_venues.groupby('Neighborhood').count()
# Out:
#                                                     Neighborhood Latitude  \
# Neighborhood
# Berczy Park                                                            60
# CN Tower , King and Spadina , Railway Lands , H...                     16
# Central Bay Street                                                     63
# Christie                                                               16
# Church and Wellesley                                                   72
# Commerce Court , Victoria Hotel                                       100
# First Canadian Place , Underground city                               100
# Garden District, Ryerson                                              100
# Harbourfront East , Union Station , Toronto Isl...                    100
# Kensington Market , Chinatown , Grange Park                            63
# Regent Park , Harbourfront                                             45
# Richmond , Adelaide , King                                             94
# Rosedale                                                                4
# St. James Town                                                         80
# St. James Town , Cabbagetown                                           45
# Toronto Dominion Centre , Design Exchange                             100
# University of Toronto , Harbord                                        32
#
#                                                     Neighborhood Longitude  \
# Neighborhood
# Berczy Park                                                             60
# CN Tower , King and Spadina , Railway Lands , H...                      16
# Central Bay Street                                                      63
# Christie                                                                16
# Church and Wellesley                                                    72
# Commerce Court , Victoria Hotel                                        100
# First Canadian Place , Underground city                                100
# Garden District, Ryerson                                               100
# Harbourfront East , Union Station , Toronto Isl...                     100
# Kensington Market , Chinatown , Grange Park                             63
# Regent Park , Harbourfront                                              45
# Richmond , Adelaide , King                                              94
# Rosedale                                                                 4
# St. James Town                                                          80
# St. James Town , Cabbagetown                                            45
# Toronto Dominion Centre , Design Exchange                              100
# University of Toronto , Harbord                                         32
#
#                                                     Venue  Venue Latitude  \
# Neighborhood
# Berczy Park                                            60              60
# CN Tower , King and Spadina , Railway Lands , H...     16              16
# Central Bay Street                                     63              63
# Christie                                               16              16
# Church and Wellesley                                   72              72
# Commerce Court , Victoria Hotel                       100             100
# First Canadian Place , Underground city               100             100
# Garden District, Ryerson                              100             100
# Harbourfront East , Union Station , Toronto Isl...    100             100
# Kensington Market , Chinatown , Grange Park            63              63
# Regent Park , Harbourfront                             45              45
# Richmond , Adelaide , King                             94              94
# Rosedale                                                4               4
# St. James Town                                         80              80
# St. James Town , Cabbagetown                           45              45
# Toronto Dominion Centre , Design Exchange             100             100
# University of Toronto , Harbord                        32              32
#
#                                                     Venue Longitude  \
# Neighborhood
# Berczy Park                                                      60
# CN Tower , King and Spadina , Railway Lands , H...               16
# Central Bay Street                                               63
# Christie                                                         16
# Church and Wellesley                                             72
# Commerce Court , Victoria Hotel                                 100
# First Canadian Place , Underground city                         100
# Garden District, Ryerson                                        100
# Harbourfront East , Union Station , Toronto Isl...              100
# Kensington Market , Chinatown , Grange Park                      63
# Regent Park , Harbourfront                                       45
# Richmond , Adelaide , King                                       94
# Rosedale                                                          4
# St. James Town                                                   80
# St. James Town , Cabbagetown                                     45
# Toronto Dominion Centre , Design Exchange                       100
# University of Toronto , Harbord                                  32
#
#                                                     Venue Category
# Neighborhood
# Berczy Park                                                     60
# CN Tower , King and Spadina , Railway Lands , H...              16
# Central Bay Street                                              63
# Christie                                                        16
# Church and Wellesley                                            72
# Commerce Court , Victoria Hotel                                100
# First Canadian Place , Underground city                        100
# Garden District, Ryerson                                       100
# Harbourfront East , Union Station , Toronto Isl...             100
# Kensington Market , Chinatown , Grange Park                     63
# Regent Park , Harbourfront                                      45
# Richmond , Adelaide , King                                      94
# Rosedale                                                         4
# St. James Town                                                  80
# St. James Town , Cabbagetown                                    45
# Toronto Dominion Centre , Design Exchange                      100
# University of Toronto , Harbord                                 32

# %%
print('There are {} uniques categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# There are 202 uniques categories.

# %% [markdown]
# ### Analyzing each neighbourhood of DownTown Toronto

# %%
# one hot encoding
downtown_onehot = pd.get_dummies(toronto_venues[['Venue Category']])
# add neighborhood column back to dataframe
downtown_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 
# move neighborhood column to the first column
fixed_columns = [downtown_onehot.columns[-1]] + list(downtown_onehot.columns[:-1])
downtown_onehot = downtown_onehot[fixed_columns]

downtown_onehot.tail()
# Out:
#               Neighborhood  Venue Category_Adult Boutique  \
# 1085  Church and Wellesley                              0
# 1086  Church and Wellesley                              0
# 1087  Church and Wellesley                              0
# 1088  Church and Wellesley                              0
# 1089  Church and Wellesley                              0
#
#       Venue Category_Airport  Venue Category_Airport Food Court  \
# 1085                       0                                  0
# 1086                       0                                  0
# 1087                       0                                  0
# 1088                       0                                  0
# 1089                       0                                  0
#
#       Venue Category_Airport Gate  Venue Category_Airport Lounge  \
# 1085                            0                              0
# 1086                            0                              0
# 1087                            0                              0
# 1088                            0                              0
# 1089                            0                              0
#
#       Venue Category_Airport Service  Venue Category_Airport Terminal  \
# 1085                               0                                0
# 1086                               0                                0
# 1087                               0                                0
# 1088                               0                                0
# 1089                               0                                0
#
#       Venue Category_American Restaurant  Venue Category_Antique Shop  ...  \
# 1085                                   0                            0  ...
# 1086                                   0                            0  ...
# 1087                                   0                            0  ...
# 1088                                   0                            0  ...
# 1089                                   0                            0  ...
#
#       Venue Category_Thai Restaurant  Venue Category_Theater  \
# 1085                               0                       0
# 1086                               0                       0
# 1087                               0                       0
# 1088                               0                       0
# 1089                               0                       0
#
#       Venue Category_Theme Restaurant  Venue Category_Trail  \
# 1085                                0                     0
# 1086                                0                     0
# 1087                                0                     0
# 1088                                0                     0
# 1089                                0                     0
#
#       Venue Category_Train Station  \
# 1085                             0
# 1086                             0
# 1087                             0
# 1088                             0
# 1089                             0
#
#       Venue Category_Vegetarian / Vegan Restaurant  \
# 1085                                             0
# 1086                                             0
# 1087                                             0
# 1088                                             0
# 1089                                             0
#
#       Venue Category_Video Game Store  Venue Category_Vietnamese Restaurant  \
# 1085                                0                                     0
# 1086                                0                                     0
# 1087                                0                                     0
# 1088                                0                                     0
# 1089                                0                                     0
#
#       Venue Category_Wine Bar  Venue Category_Yoga Studio
# 1085                        0                           0
# 1086                        0                           0
# 1087                        0                           0
# 1088                        0                           0
# 1089                        0                           0
#
# [5 rows x 203 columns]

# %%
downtown_onehot.shape
# Out:
# (1090, 203)

# %% [markdown]
# ### Lets find the mean of hot encoded categorical variables in a neighbourhood

# %%
downtown_grouped = downtown_onehot.groupby('Neighborhood').mean().reset_index()
downtown_grouped.shape
# Out:
# (17, 203)

# %%
downtown_grouped
# Out:
#                                          Neighborhood  \
# 0                                         Berczy Park
# 1   CN Tower , King and Spadina , Railway Lands , ...
# 2                                  Central Bay Street
# 3                                            Christie
# 4                                Church and Wellesley
# 5                     Commerce Court , Victoria Hotel
# 6             First Canadian Place , Underground city
# 7                            Garden District, Ryerson
# 8   Harbourfront East , Union Station , Toronto Is...
# 9         Kensington Market , Chinatown , Grange Park
# 10                         Regent Park , Harbourfront
# 11                         Richmond , Adelaide , King
# 12                                           Rosedale
# 13                                     St. James Town
# 14                       St. James Town , Cabbagetown
# 15          Toronto Dominion Centre , Design Exchange
# 16                    University of Toronto , Harbord
#
#     Venue Category_Adult Boutique  Venue Category_Airport  \
# 0                        0.000000                  0.0000
# 1                        0.000000                  0.0625
# 2                        0.000000                  0.0000
# 3                        0.000000                  0.0000
# 4                        0.013889                  0.0000
# 5                        0.000000                  0.0000
# 6                        0.000000                  0.0000
# 7                        0.000000                  0.0000
# 8                        0.000000                  0.0000
# 9                        0.000000                  0.0000
# 10                       0.000000                  0.0000
# 11                       0.000000                  0.0000
# 12                       0.000000                  0.0000
# 13                       0.000000                  0.0000
# 14                       0.000000                  0.0000
# 15                       0.000000                  0.0000
# 16                       0.000000                  0.0000
#
#     Venue Category_Airport Food Court  Venue Category_Airport Gate  \
# 0                              0.0000                       0.0000
# 1                              0.0625                       0.0625
# 2                              0.0000                       0.0000
# 3                              0.0000                       0.0000
# 4                              0.0000                       0.0000
# 5                              0.0000                       0.0000
# 6                              0.0000                       0.0000
# 7                              0.0000                       0.0000
# 8                              0.0000                       0.0000
# 9                              0.0000                       0.0000
# 10                             0.0000                       0.0000
# 11                             0.0000                       0.0000
# 12                             0.0000                       0.0000
# 13                             0.0000                       0.0000
# 14                             0.0000                       0.0000
# 15                             0.0000                       0.0000
# 16                             0.0000                       0.0000
#
#     Venue Category_Airport Lounge  Venue Category_Airport Service  \
# 0                           0.000                          0.0000
# 1                           0.125                          0.0625
# 2                           0.000                          0.0000
# 3                           0.000                          0.0000
# 4                           0.000                          0.0000
# 5                           0.000                          0.0000
# 6                           0.000                          0.0000
# 7                           0.000                          0.0000
# 8                           0.000                          0.0000
# 9                           0.000                          0.0000
# 10                          0.000                          0.0000
# 11                          0.000                          0.0000
# 12                          0.000                          0.0000
# 13                          0.000                          0.0000
# 14                          0.000                          0.0000
# 15                          0.000                          0.0000
# 16                          0.000                          0.0000
#
#     Venue Category_Airport Terminal  Venue Category_American Restaurant  \
# 0                             0.000                            0.000000
# 1                             0.125                            0.000000
# 2                             0.000                            0.000000
# 3                             0.000                            0.000000
# 4                             0.000                            0.013889
# 5                             0.000                            0.030000
# 6                             0.000                            0.030000
# 7                             0.000                            0.000000
# 8                             0.000                            0.000000
# 9                             0.000                            0.000000
# 10                            0.000                            0.000000
# 11                            0.000                            0.010638
# 12                            0.000                            0.000000
# 13                            0.000                            0.025000
# 14                            0.000                            0.000000
# 15                            0.000                            0.020000
# 16                            0.000                            0.000000
#
#     Venue Category_Antique Shop  ...  Venue Category_Thai Restaurant  \
# 0                      0.000000  ...                        0.016667
# 1                      0.000000  ...                        0.000000
# 2                      0.000000  ...                        0.031746
# 3                      0.000000  ...                        0.000000
# 4                      0.000000  ...                        0.013889
# 5                      0.000000  ...                        0.020000
# 6                      0.000000  ...                        0.020000
# 7                      0.000000  ...                        0.020000
# 8                      0.000000  ...                        0.000000
# 9                      0.000000  ...                        0.000000
# 10                     0.022222  ...                        0.000000
# 11                     0.000000  ...                        0.031915
# 12                     0.000000  ...                        0.000000
# 13                     0.000000  ...                        0.012500
# 14                     0.000000  ...                        0.022222
# 15                     0.000000  ...                        0.000000
# 16                     0.000000  ...                        0.000000
#
#     Venue Category_Theater  Venue Category_Theme Restaurant  \
# 0                 0.000000                         0.000000
# 1                 0.000000                         0.000000
# 2                 0.000000                         0.000000
# 3                 0.000000                         0.000000
# 4                 0.013889                         0.013889
# 5                 0.000000                         0.000000
# 6                 0.010000                         0.000000
# 7                 0.020000                         0.000000
# 8                 0.010000                         0.000000
# 9                 0.000000                         0.000000
# 10                0.044444                         0.000000
# 11                0.010638                         0.000000
# 12                0.000000                         0.000000
# 13                0.012500                         0.000000
# 14                0.000000                         0.000000
# 15                0.010000                         0.000000
# 16                0.031250                         0.000000
#
#     Venue Category_Trail  Venue Category_Train Station  \
# 0                   0.00                          0.00
# 1                   0.00                          0.00
# 2                   0.00                          0.00
# 3                   0.00                          0.00
# 4                   0.00                          0.00
# 5                   0.00                          0.00
# 6                   0.00                          0.01
# 7                   0.00                          0.00
# 8                   0.00                          0.01
# 9                   0.00                          0.00
# 10                  0.00                          0.00
# 11                  0.00                          0.00
# 12                  0.25                          0.00
# 13                  0.00                          0.00
# 14                  0.00                          0.00
# 15                  0.00                          0.01
# 16                  0.00                          0.00
#
#     Venue Category_Vegetarian / Vegan Restaurant  \
# 0                                       0.016667
# 1                                       0.000000
# 2                                       0.015873
# 3                                       0.000000
# 4                                       0.000000
# 5                                       0.020000
# 6                                       0.010000
# 7                                       0.000000
# 8                                       0.010000
# 9                                       0.047619
# 10                                      0.000000
# 11                                      0.010638
# 12                                      0.000000
# 13                                      0.012500
# 14                                      0.000000
# 15                                      0.010000
# 16                                      0.000000
#
#     Venue Category_Video Game Store  Venue Category_Vietnamese Restaurant  \
# 0                           0.00000                              0.000000
# 1                           0.00000                              0.000000
# 2                           0.00000                              0.000000
# 3                           0.00000                              0.000000
# 4                           0.00000                              0.000000
# 5                           0.00000                              0.000000
# 6                           0.00000                              0.000000
# 7                           0.00000                              0.010000
# 8                           0.00000                              0.000000
# 9                           0.00000                              0.047619
# 10                          0.00000                              0.000000
# 11                          0.00000                              0.000000
# 12                          0.00000                              0.000000
# 13                          0.00000                              0.000000
# 14                          0.00000                              0.000000
# 15                          0.00000                              0.000000
# 16                          0.03125                              0.000000
#
#     Venue Category_Wine Bar  Venue Category_Yoga Studio
# 0                  0.000000                    0.000000
# 1                  0.000000                    0.000000
# 2                  0.015873                    0.015873
# 3                  0.000000                    0.000000
# 4                  0.000000                    0.027778
# 5                  0.010000                    0.000000
# 6                  0.010000                    0.000000
# 7                  0.010000                    0.000000
# 8                  0.010000                    0.000000
# 9                  0.015873                    0.000000
# 10                 0.000000                    0.022222
# 11                 0.000000                    0.000000
# 12                 0.000000                    0.000000
# 13                 0.012500                    0.000000
# 14                 0.000000                    0.000000
# 15                 0.010000                    0.000000
# 16                 0.000000                    0.031250
#
# [17 rows x 203 columns]

# %%
num_top_venues = 5

for hood in downtown_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = downtown_grouped[downtown_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Berczy Park----
#                            venue  freq
# 0     Venue Category_Coffee Shop  0.08
# 1    Venue Category_Cocktail Bar  0.05
# 2          Venue Category_Bakery  0.05
# 3        Venue Category_Pharmacy  0.03
# 4  Venue Category_Farmers Market  0.03
#
#
# ----CN Tower , King and Spadina , Railway Lands , Harbourfront West , Bathurst Quay , South Niagara , Island airport----
#                                 venue  freq
# 0       Venue Category_Airport Lounge  0.12
# 1     Venue Category_Airport Terminal  0.12
# 2        Venue Category_Boat or Ferry  0.06
# 3              Venue Category_Airport  0.06
# 4  Venue Category_Rental Car Location  0.06
#
#
# ----Central Bay Street----
#                                 venue  freq
# 0          Venue Category_Coffee Shop  0.17
# 1   Venue Category_Italian Restaurant  0.05
# 2       Venue Category_Sandwich Place  0.05
# 3                 Venue Category_Café  0.05
# 4  Venue Category_Japanese Restaurant  0.03
#
#
# ----Christie----
#                           venue  freq
# 0  Venue Category_Grocery Store  0.25
# 1           Venue Category_Café  0.19
# 2           Venue Category_Park  0.12
# 3    Venue Category_Candy Store  0.06
# 4     Venue Category_Baby Store  0.06
#
#
# ----Church and Wellesley----
#                                 venue  freq
# 0          Venue Category_Coffee Shop  0.08
# 1     Venue Category_Sushi Restaurant  0.07
# 2  Venue Category_Japanese Restaurant  0.07
# 3           Venue Category_Restaurant  0.04
# 4          Venue Category_Yoga Studio  0.03
#
#
# ----Commerce Court , Victoria Hotel----
#                         venue  freq
# 0  Venue Category_Coffee Shop  0.12
# 1   Venue Category_Restaurant  0.07
# 2         Venue Category_Café  0.06
# 3        Venue Category_Hotel  0.05
# 4          Venue Category_Gym  0.04
#
#
# ----First Canadian Place , Underground city----
#                         venue  freq
# 0  Venue Category_Coffee Shop  0.10
# 1         Venue Category_Café  0.07
# 2        Venue Category_Hotel  0.05
# 3          Venue Category_Gym  0.04
# 4   Venue Category_Restaurant  0.04
#
#
# ----Garden District, Ryerson----
#                                       venue  freq
# 0             Venue Category_Clothing Store  0.09
# 1                Venue Category_Coffee Shop  0.08
# 2             Venue Category_Cosmetics Shop  0.03
# 3            Venue Category_Bubble Tea Shop  0.03
# 4  Venue Category_Middle Eastern Restaurant  0.03
#
#
# ----Harbourfront East , Union Station , Toronto Islands----
#                         venue  freq
# 0  Venue Category_Coffee Shop  0.12
# 1     Venue Category_Aquarium  0.05
# 2         Venue Category_Café  0.04
# 3        Venue Category_Hotel  0.04
# 4      Venue Category_Brewery  0.03
#
#
# ----Kensington Market , Chinatown , Grange Park----
#                                           venue  freq
# 0                           Venue Category_Café  0.08
# 1                    Venue Category_Coffee Shop  0.06
# 2             Venue Category_Mexican Restaurant  0.05
# 3          Venue Category_Vietnamese Restaurant  0.05
# 4  Venue Category_Vegetarian / Vegan Restaurant  0.05
#
#
# ----Regent Park , Harbourfront----
#                            venue  freq
# 0     Venue Category_Coffee Shop  0.18
# 1             Venue Category_Pub  0.07
# 2            Venue Category_Park  0.07
# 3          Venue Category_Bakery  0.07
# 4  Venue Category_Breakfast Spot  0.04
#
#
# ----Richmond , Adelaide , King----
#                            venue  freq
# 0     Venue Category_Coffee Shop  0.11
# 1            Venue Category_Café  0.05
# 2      Venue Category_Restaurant  0.04
# 3  Venue Category_Clothing Store  0.03
# 4           Venue Category_Hotel  0.03
#
#
# ----Rosedale----
#                            venue  freq
# 0            Venue Category_Park  0.50
# 1      Venue Category_Playground  0.25
# 2           Venue Category_Trail  0.25
# 3  Venue Category_Adult Boutique  0.00
# 4   Venue Category_Movie Theater  0.00
#
#
# ----St. James Town----
#                            venue  freq
# 0     Venue Category_Coffee Shop  0.06
# 1            Venue Category_Café  0.06
# 2       Venue Category_Gastropub  0.04
# 3  Venue Category_Cosmetics Shop  0.04
# 4      Venue Category_Restaurant  0.04
#
#
# ----St. James Town , Cabbagetown----
#                                venue  freq
# 0         Venue Category_Coffee Shop  0.09
# 1        Venue Category_Gourmet Shop  0.04
# 2  Venue Category_Italian Restaurant  0.04
# 3         Venue Category_Pizza Place  0.04
# 4              Venue Category_Bakery  0.04
#
#
# ----Toronto Dominion Centre , Design Exchange----
#                                venue  freq
# 0         Venue Category_Coffee Shop  0.12
# 1               Venue Category_Hotel  0.07
# 2                Venue Category_Café  0.06
# 3          Venue Category_Restaurant  0.04
# 4  Venue Category_Seafood Restaurant  0.03
#
#
# ----University of Toronto , Harbord----
#                                 venue  freq
# 0                 Venue Category_Café  0.16
# 1               Venue Category_Bakery  0.06
# 2   Venue Category_Italian Restaurant  0.06
# 3  Venue Category_Japanese Restaurant  0.06
# 4                  Venue Category_Bar  0.06

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = downtown_grouped['Neighborhood']

for ind in np.arange(downtown_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(downtown_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head(20)
# Out:
#                                          Neighborhood  \
# 0                                         Berczy Park
# 1   CN Tower , King and Spadina , Railway Lands , ...
# 2                                  Central Bay Street
# 3                                            Christie
# 4                                Church and Wellesley
# 5                     Commerce Court , Victoria Hotel
# 6             First Canadian Place , Underground city
# 7                            Garden District, Ryerson
# 8   Harbourfront East , Union Station , Toronto Is...
# 9         Kensington Market , Chinatown , Grange Park
# 10                         Regent Park , Harbourfront
# 11                         Richmond , Adelaide , King
# 12                                           Rosedale
# 13                                     St. James Town
# 14                       St. James Town , Cabbagetown
# 15          Toronto Dominion Centre , Design Exchange
# 16                    University of Toronto , Harbord
#
#             1st Most Common Venue               2nd Most Common Venue  \
# 0      Venue Category_Coffee Shop         Venue Category_Cocktail Bar
# 1   Venue Category_Airport Lounge     Venue Category_Airport Terminal
# 2      Venue Category_Coffee Shop   Venue Category_Italian Restaurant
# 3    Venue Category_Grocery Store                 Venue Category_Café
# 4      Venue Category_Coffee Shop  Venue Category_Japanese Restaurant
# 5      Venue Category_Coffee Shop           Venue Category_Restaurant
# 6      Venue Category_Coffee Shop                 Venue Category_Café
# 7   Venue Category_Clothing Store          Venue Category_Coffee Shop
# 8      Venue Category_Coffee Shop             Venue Category_Aquarium
# 9             Venue Category_Café          Venue Category_Coffee Shop
# 10     Venue Category_Coffee Shop                 Venue Category_Park
# 11     Venue Category_Coffee Shop                 Venue Category_Café
# 12            Venue Category_Park           Venue Category_Playground
# 13     Venue Category_Coffee Shop                 Venue Category_Café
# 14     Venue Category_Coffee Shop               Venue Category_Bakery
# 15     Venue Category_Coffee Shop                Venue Category_Hotel
# 16            Venue Category_Café            Venue Category_Bookstore
#
#                    3rd Most Common Venue  \
# 0                  Venue Category_Bakery
# 1                   Venue Category_Plane
# 2          Venue Category_Sandwich Place
# 3                    Venue Category_Park
# 4        Venue Category_Sushi Restaurant
# 5                    Venue Category_Café
# 6                   Venue Category_Hotel
# 7          Venue Category_Cosmetics Shop
# 8                   Venue Category_Hotel
# 9   Venue Category_Vietnamese Restaurant
# 10                 Venue Category_Bakery
# 11             Venue Category_Restaurant
# 12                  Venue Category_Trail
# 13              Venue Category_Gastropub
# 14             Venue Category_Restaurant
# 15                   Venue Category_Café
# 16                    Venue Category_Bar
#
#                            4th Most Common Venue  \
# 0                     Venue Category_Cheese Shop
# 1                 Venue Category_Harbor / Marina
# 2                            Venue Category_Café
# 3                     Venue Category_Candy Store
# 4                      Venue Category_Restaurant
# 5                           Venue Category_Hotel
# 6                      Venue Category_Restaurant
# 7                 Venue Category_Bubble Tea Shop
# 8                            Venue Category_Café
# 9   Venue Category_Vegetarian / Vegan Restaurant
# 10                            Venue Category_Pub
# 11                Venue Category_Thai Restaurant
# 12                   Venue Category_Dance Studio
# 13                   Venue Category_Cocktail Bar
# 14                            Venue Category_Pub
# 15                     Venue Category_Restaurant
# 16             Venue Category_Italian Restaurant
#
#                  5th Most Common Venue  \
# 0        Venue Category_Farmers Market
# 1      Venue Category_Sculpture Garden
# 2       Venue Category_Thai Restaurant
# 3    Venue Category_Italian Restaurant
# 4           Venue Category_Yoga Studio
# 5                   Venue Category_Gym
# 6   Venue Category_Japanese Restaurant
# 7                  Venue Category_Café
# 8   Venue Category_Sporting Goods Shop
# 9    Venue Category_Mexican Restaurant
# 10       Venue Category_Breakfast Spot
# 11                Venue Category_Hotel
# 12  Venue Category_Dumpling Restaurant
# 13           Venue Category_Restaurant
# 14   Venue Category_Italian Restaurant
# 15          Venue Category_Salad Place
# 16  Venue Category_Japanese Restaurant
#
#                        6th Most Common Venue  \
# 0                    Venue Category_Pharmacy
# 1               Venue Category_Boat or Ferry
# 2                 Venue Category_Salad Place
# 3          Venue Category_Athletics & Sports
# 4                         Venue Category_Pub
# 5          Venue Category_Italian Restaurant
# 6                         Venue Category_Gym
# 7   Venue Category_Middle Eastern Restaurant
# 8          Venue Category_Italian Restaurant
# 9               Venue Category_Grocery Store
# 10                       Venue Category_Café
# 11              Venue Category_Deli / Bodega
# 12                 Venue Category_Donut Shop
# 13             Venue Category_Cosmetics Shop
# 14                       Venue Category_Café
# 15         Venue Category_Seafood Restaurant
# 16                     Venue Category_Bakery
#
#                  7th Most Common Venue  \
# 0            Venue Category_Restaurant
# 1   Venue Category_Rental Car Location
# 2       Venue Category_Bubble Tea Shop
# 3            Venue Category_Restaurant
# 4           Venue Category_Men's Store
# 5   Venue Category_American Restaurant
# 6      Venue Category_Asian Restaurant
# 7   Venue Category_Japanese Restaurant
# 8        Venue Category_Scenic Lookout
# 9          Venue Category_Dessert Shop
# 10              Venue Category_Theater
# 11       Venue Category_Clothing Store
# 12     Venue Category_Doner Restaurant
# 13                  Venue Category_Gym
# 14         Venue Category_Gourmet Shop
# 15  Venue Category_Japanese Restaurant
# 16          Venue Category_Yoga Studio
#
#                       8th Most Common Venue  \
# 0         Venue Category_Seafood Restaurant
# 1                        Venue Category_Bar
# 2               Venue Category_Burger Joint
# 3                 Venue Category_Baby Store
# 4   Venue Category_Mediterranean Restaurant
# 5         Venue Category_Seafood Restaurant
# 6         Venue Category_Seafood Restaurant
# 7       Venue Category_Fast Food Restaurant
# 8                    Venue Category_Brewery
# 9             Venue Category_Farmers Market
# 10        Venue Category_Mexican Restaurant
# 11                       Venue Category_Gym
# 12                   Venue Category_Dog Run
# 13            Venue Category_Farmers Market
# 14               Venue Category_Pizza Place
# 15        Venue Category_Italian Restaurant
# 16                  Venue Category_Beer Bar
#
#                      9th Most Common Venue  \
# 0                  Venue Category_Beer Bar
# 1               Venue Category_Coffee Shop
# 2       Venue Category_Japanese Restaurant
# 3                 Venue Category_Nightclub
# 4                     Venue Category_Hotel
# 5              Venue Category_Cocktail Bar
# 6               Venue Category_Salad Place
# 7                 Venue Category_Bookstore
# 8                Venue Category_Restaurant
# 9                      Venue Category_Park
# 10               Venue Category_Restaurant
# 11              Venue Category_Pizza Place
# 12      Venue Category_Distribution Center
# 13      Venue Category_Moroccan Restaurant
# 14        Venue Category_Indian Restaurant
# 15      Venue Category_Sporting Goods Shop
# 16  Venue Category_Comfort Food Restaurant
#
#                        10th Most Common Venue
# 0              Venue Category_Thai Restaurant
# 1                     Venue Category_Boutique
# 2   Venue Category_Modern European Restaurant
# 3                  Venue Category_Coffee Shop
# 4                      Venue Category_Gay Bar
# 5          Venue Category_Japanese Restaurant
# 6                Venue Category_Deli / Bodega
# 7             Venue Category_Ramen Restaurant
# 8          Venue Category_Fried Chicken Joint
# 9                          Venue Category_Bar
# 10              Venue Category_Chocolate Shop
# 11                Venue Category_Concert Hall
# 12              Venue Category_Discount Store
# 13            Venue Category_Department Store
# 14                        Venue Category_Park
# 15            Venue Category_Sushi Restaurant
# 16              Venue Category_Sandwich Place

# %% [markdown]
# ## Cluster Neighborhoods

# %%
# set number of clusters
kclusters = 5

downtown_grouped_clustering = downtown_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(downtown_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0, 3, 0, 2, 0, 0, 0, 0, 0, 0], dtype=int32)

# %%
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)
neighborhoods_venues_sorted
# Out:
#     Cluster Labels                                       Neighborhood  \
# 0                0                                        Berczy Park
# 1                3  CN Tower , King and Spadina , Railway Lands , ...
# 2                0                                 Central Bay Street
# 3                2                                           Christie
# 4                0                               Church and Wellesley
# 5                0                    Commerce Court , Victoria Hotel
# 6                0            First Canadian Place , Underground city
# 7                0                           Garden District, Ryerson
# 8                0  Harbourfront East , Union Station , Toronto Is...
# 9                0        Kensington Market , Chinatown , Grange Park
# 10               0                         Regent Park , Harbourfront
# 11               0                         Richmond , Adelaide , King
# 12               1                                           Rosedale
# 13               0                                     St. James Town
# 14               0                       St. James Town , Cabbagetown
# 15               0          Toronto Dominion Centre , Design Exchange
# 16               4                    University of Toronto , Harbord
#
#             1st Most Common Venue               2nd Most Common Venue  \
# 0      Venue Category_Coffee Shop         Venue Category_Cocktail Bar
# 1   Venue Category_Airport Lounge     Venue Category_Airport Terminal
# 2      Venue Category_Coffee Shop   Venue Category_Italian Restaurant
# 3    Venue Category_Grocery Store                 Venue Category_Café
# 4      Venue Category_Coffee Shop  Venue Category_Japanese Restaurant
# 5      Venue Category_Coffee Shop           Venue Category_Restaurant
# 6      Venue Category_Coffee Shop                 Venue Category_Café
# 7   Venue Category_Clothing Store          Venue Category_Coffee Shop
# 8      Venue Category_Coffee Shop             Venue Category_Aquarium
# 9             Venue Category_Café          Venue Category_Coffee Shop
# 10     Venue Category_Coffee Shop                 Venue Category_Park
# 11     Venue Category_Coffee Shop                 Venue Category_Café
# 12            Venue Category_Park           Venue Category_Playground
# 13     Venue Category_Coffee Shop                 Venue Category_Café
# 14     Venue Category_Coffee Shop               Venue Category_Bakery
# 15     Venue Category_Coffee Shop                Venue Category_Hotel
# 16            Venue Category_Café            Venue Category_Bookstore
#
#                    3rd Most Common Venue  \
# 0                  Venue Category_Bakery
# 1                   Venue Category_Plane
# 2          Venue Category_Sandwich Place
# 3                    Venue Category_Park
# 4        Venue Category_Sushi Restaurant
# 5                    Venue Category_Café
# 6                   Venue Category_Hotel
# 7          Venue Category_Cosmetics Shop
# 8                   Venue Category_Hotel
# 9   Venue Category_Vietnamese Restaurant
# 10                 Venue Category_Bakery
# 11             Venue Category_Restaurant
# 12                  Venue Category_Trail
# 13              Venue Category_Gastropub
# 14             Venue Category_Restaurant
# 15                   Venue Category_Café
# 16                    Venue Category_Bar
#
#                            4th Most Common Venue  \
# 0                     Venue Category_Cheese Shop
# 1                 Venue Category_Harbor / Marina
# 2                            Venue Category_Café
# 3                     Venue Category_Candy Store
# 4                      Venue Category_Restaurant
# 5                           Venue Category_Hotel
# 6                      Venue Category_Restaurant
# 7                 Venue Category_Bubble Tea Shop
# 8                            Venue Category_Café
# 9   Venue Category_Vegetarian / Vegan Restaurant
# 10                            Venue Category_Pub
# 11                Venue Category_Thai Restaurant
# 12                   Venue Category_Dance Studio
# 13                   Venue Category_Cocktail Bar
# 14                            Venue Category_Pub
# 15                     Venue Category_Restaurant
# 16             Venue Category_Italian Restaurant
#
#                  5th Most Common Venue  \
# 0        Venue Category_Farmers Market
# 1      Venue Category_Sculpture Garden
# 2       Venue Category_Thai Restaurant
# 3    Venue Category_Italian Restaurant
# 4           Venue Category_Yoga Studio
# 5                   Venue Category_Gym
# 6   Venue Category_Japanese Restaurant
# 7                  Venue Category_Café
# 8   Venue Category_Sporting Goods Shop
# 9    Venue Category_Mexican Restaurant
# 10       Venue Category_Breakfast Spot
# 11                Venue Category_Hotel
# 12  Venue Category_Dumpling Restaurant
# 13           Venue Category_Restaurant
# 14   Venue Category_Italian Restaurant
# 15          Venue Category_Salad Place
# 16  Venue Category_Japanese Restaurant
#
#                        6th Most Common Venue  \
# 0                    Venue Category_Pharmacy
# 1               Venue Category_Boat or Ferry
# 2                 Venue Category_Salad Place
# 3          Venue Category_Athletics & Sports
# 4                         Venue Category_Pub
# 5          Venue Category_Italian Restaurant
# 6                         Venue Category_Gym
# 7   Venue Category_Middle Eastern Restaurant
# 8          Venue Category_Italian Restaurant
# 9               Venue Category_Grocery Store
# 10                       Venue Category_Café
# 11              Venue Category_Deli / Bodega
# 12                 Venue Category_Donut Shop
# 13             Venue Category_Cosmetics Shop
# 14                       Venue Category_Café
# 15         Venue Category_Seafood Restaurant
# 16                     Venue Category_Bakery
#
#                  7th Most Common Venue  \
# 0            Venue Category_Restaurant
# 1   Venue Category_Rental Car Location
# 2       Venue Category_Bubble Tea Shop
# 3            Venue Category_Restaurant
# 4           Venue Category_Men's Store
# 5   Venue Category_American Restaurant
# 6      Venue Category_Asian Restaurant
# 7   Venue Category_Japanese Restaurant
# 8        Venue Category_Scenic Lookout
# 9          Venue Category_Dessert Shop
# 10              Venue Category_Theater
# 11       Venue Category_Clothing Store
# 12     Venue Category_Doner Restaurant
# 13                  Venue Category_Gym
# 14         Venue Category_Gourmet Shop
# 15  Venue Category_Japanese Restaurant
# 16          Venue Category_Yoga Studio
#
#                       8th Most Common Venue  \
# 0         Venue Category_Seafood Restaurant
# 1                        Venue Category_Bar
# 2               Venue Category_Burger Joint
# 3                 Venue Category_Baby Store
# 4   Venue Category_Mediterranean Restaurant
# 5         Venue Category_Seafood Restaurant
# 6         Venue Category_Seafood Restaurant
# 7       Venue Category_Fast Food Restaurant
# 8                    Venue Category_Brewery
# 9             Venue Category_Farmers Market
# 10        Venue Category_Mexican Restaurant
# 11                       Venue Category_Gym
# 12                   Venue Category_Dog Run
# 13            Venue Category_Farmers Market
# 14               Venue Category_Pizza Place
# 15        Venue Category_Italian Restaurant
# 16                  Venue Category_Beer Bar
#
#                      9th Most Common Venue  \
# 0                  Venue Category_Beer Bar
# 1               Venue Category_Coffee Shop
# 2       Venue Category_Japanese Restaurant
# 3                 Venue Category_Nightclub
# 4                     Venue Category_Hotel
# 5              Venue Category_Cocktail Bar
# 6               Venue Category_Salad Place
# 7                 Venue Category_Bookstore
# 8                Venue Category_Restaurant
# 9                      Venue Category_Park
# 10               Venue Category_Restaurant
# 11              Venue Category_Pizza Place
# 12      Venue Category_Distribution Center
# 13      Venue Category_Moroccan Restaurant
# 14        Venue Category_Indian Restaurant
# 15      Venue Category_Sporting Goods Shop
# 16  Venue Category_Comfort Food Restaurant
#
#                        10th Most Common Venue
# 0              Venue Category_Thai Restaurant
# 1                     Venue Category_Boutique
# 2   Venue Category_Modern European Restaurant
# 3                  Venue Category_Coffee Shop
# 4                      Venue Category_Gay Bar
# 5          Venue Category_Japanese Restaurant
# 6                Venue Category_Deli / Bodega
# 7             Venue Category_Ramen Restaurant
# 8          Venue Category_Fried Chicken Joint
# 9                          Venue Category_Bar
# 10              Venue Category_Chocolate Shop
# 11                Venue Category_Concert Hall
# 12              Venue Category_Discount Store
# 13            Venue Category_Department Store
# 14                        Venue Category_Park
# 15            Venue Category_Sushi Restaurant
# 16              Venue Category_Sandwich Place

# %%
downtown_df.head()
# Out:
#   PostalCode           Borough               Neighbourhood   Latitude  \
# 0        M5A  Downtown Toronto  Regent Park , Harbourfront  43.654260
# 1        M5B  Downtown Toronto    Garden District, Ryerson  43.657162
# 2        M5C  Downtown Toronto              St. James Town  43.651494
# 3        M5E  Downtown Toronto                 Berczy Park  43.644771
# 4        M5G  Downtown Toronto          Central Bay Street  43.657952
#
#    Longitude
# 0 -79.360636
# 1 -79.378937
# 2 -79.375418
# 3 -79.373306
# 4 -79.387383

# %%
downtown_merged = downtown_df

# merge manhattan_grouped with manhattan_data to add latitude/longitude for each neighborhood
downtown_merged = downtown_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighbourhood')

downtown_merged.head() # check the last columns!
# Out:
#   PostalCode           Borough               Neighbourhood   Latitude  \
# 0        M5A  Downtown Toronto  Regent Park , Harbourfront  43.654260
# 1        M5B  Downtown Toronto    Garden District, Ryerson  43.657162
# 2        M5C  Downtown Toronto              St. James Town  43.651494
# 3        M5E  Downtown Toronto                 Berczy Park  43.644771
# 4        M5G  Downtown Toronto          Central Bay Street  43.657952
#
#    Longitude  Cluster Labels          1st Most Common Venue  \
# 0 -79.360636               0     Venue Category_Coffee Shop
# 1 -79.378937               0  Venue Category_Clothing Store
# 2 -79.375418               0     Venue Category_Coffee Shop
# 3 -79.373306               0     Venue Category_Coffee Shop
# 4 -79.387383               0     Venue Category_Coffee Shop
#
#                2nd Most Common Venue          3rd Most Common Venue  \
# 0                Venue Category_Park          Venue Category_Bakery
# 1         Venue Category_Coffee Shop  Venue Category_Cosmetics Shop
# 2                Venue Category_Café       Venue Category_Gastropub
# 3        Venue Category_Cocktail Bar          Venue Category_Bakery
# 4  Venue Category_Italian Restaurant  Venue Category_Sandwich Place
#
#             4th Most Common Venue           5th Most Common Venue  \
# 0              Venue Category_Pub   Venue Category_Breakfast Spot
# 1  Venue Category_Bubble Tea Shop             Venue Category_Café
# 2     Venue Category_Cocktail Bar       Venue Category_Restaurant
# 3      Venue Category_Cheese Shop   Venue Category_Farmers Market
# 4             Venue Category_Café  Venue Category_Thai Restaurant
#
#                       6th Most Common Venue  \
# 0                       Venue Category_Café
# 1  Venue Category_Middle Eastern Restaurant
# 2             Venue Category_Cosmetics Shop
# 3                   Venue Category_Pharmacy
# 4                Venue Category_Salad Place
#
#                 7th Most Common Venue                8th Most Common Venue  \
# 0              Venue Category_Theater    Venue Category_Mexican Restaurant
# 1  Venue Category_Japanese Restaurant  Venue Category_Fast Food Restaurant
# 2                  Venue Category_Gym        Venue Category_Farmers Market
# 3           Venue Category_Restaurant    Venue Category_Seafood Restaurant
# 4      Venue Category_Bubble Tea Shop          Venue Category_Burger Joint
#
#                 9th Most Common Venue  \
# 0           Venue Category_Restaurant
# 1            Venue Category_Bookstore
# 2  Venue Category_Moroccan Restaurant
# 3             Venue Category_Beer Bar
# 4  Venue Category_Japanese Restaurant
#
#                       10th Most Common Venue
# 0              Venue Category_Chocolate Shop
# 1            Venue Category_Ramen Restaurant
# 2            Venue Category_Department Store
# 3             Venue Category_Thai Restaurant
# 4  Venue Category_Modern European Restaurant

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(downtown_merged['Latitude'], downtown_merged['Longitude'], downtown_merged['Neighbourhood'], downtown_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_1b625fb775e34b5f9ac5f17058e98a35%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_1b625fb775e34b5f9ac5f17058e98a35%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_1b625fb775e34b5f9ac5f17058e98a35%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_1b625fb775e34b5f9ac5f17058e98a35%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B43.6541737%2C-79.38081164513409%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20% ...

# %%
downtown_merged.loc[downtown_merged['Cluster Labels'] == 0, 
                    downtown_merged.columns[[1] + list(range(5, downtown_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels          1st Most Common Venue  \
# 0   Downtown Toronto               0     Venue Category_Coffee Shop
# 1   Downtown Toronto               0  Venue Category_Clothing Store
# 2   Downtown Toronto               0     Venue Category_Coffee Shop
# 3   Downtown Toronto               0     Venue Category_Coffee Shop
# 4   Downtown Toronto               0     Venue Category_Coffee Shop
# 6   Downtown Toronto               0     Venue Category_Coffee Shop
# 7   Downtown Toronto               0     Venue Category_Coffee Shop
# 8   Downtown Toronto               0     Venue Category_Coffee Shop
# 9   Downtown Toronto               0     Venue Category_Coffee Shop
# 11  Downtown Toronto               0            Venue Category_Café
# 14  Downtown Toronto               0     Venue Category_Coffee Shop
# 15  Downtown Toronto               0     Venue Category_Coffee Shop
# 16  Downtown Toronto               0     Venue Category_Coffee Shop
#
#                  2nd Most Common Venue                 3rd Most Common Venue  \
# 0                  Venue Category_Park                 Venue Category_Bakery
# 1           Venue Category_Coffee Shop         Venue Category_Cosmetics Shop
# 2                  Venue Category_Café              Venue Category_Gastropub
# 3          Venue Category_Cocktail Bar                 Venue Category_Bakery
# 4    Venue Category_Italian Restaurant         Venue Category_Sandwich Place
# 6                  Venue Category_Café             Venue Category_Restaurant
# 7              Venue Category_Aquarium                  Venue Category_Hotel
# 8                 Venue Category_Hotel                   Venue Category_Café
# 9            Venue Category_Restaurant                   Venue Category_Café
# 11          Venue Category_Coffee Shop  Venue Category_Vietnamese Restaurant
# 14               Venue Category_Bakery             Venue Category_Restaurant
# 15                 Venue Category_Café                  Venue Category_Hotel
# 16  Venue Category_Japanese Restaurant       Venue Category_Sushi Restaurant
#
#                            4th Most Common Venue  \
# 0                             Venue Category_Pub
# 1                 Venue Category_Bubble Tea Shop
# 2                    Venue Category_Cocktail Bar
# 3                     Venue Category_Cheese Shop
# 4                            Venue Category_Café
# 6                 Venue Category_Thai Restaurant
# 7                            Venue Category_Café
# 8                      Venue Category_Restaurant
# 9                           Venue Category_Hotel
# 11  Venue Category_Vegetarian / Vegan Restaurant
# 14                            Venue Category_Pub
# 15                     Venue Category_Restaurant
# 16                     Venue Category_Restaurant
#
#                  5th Most Common Venue  \
# 0        Venue Category_Breakfast Spot
# 1                  Venue Category_Café
# 2            Venue Category_Restaurant
# 3        Venue Category_Farmers Market
# 4       Venue Category_Thai Restaurant
# 6                 Venue Category_Hotel
# 7   Venue Category_Sporting Goods Shop
# 8           Venue Category_Salad Place
# 9                   Venue Category_Gym
# 11   Venue Category_Mexican Restaurant
# 14   Venue Category_Italian Restaurant
# 15  Venue Category_Japanese Restaurant
# 16          Venue Category_Yoga Studio
#
#                        6th Most Common Venue  \
# 0                        Venue Category_Café
# 1   Venue Category_Middle Eastern Restaurant
# 2              Venue Category_Cosmetics Shop
# 3                    Venue Category_Pharmacy
# 4                 Venue Category_Salad Place
# 6               Venue Category_Deli / Bodega
# 7          Venue Category_Italian Restaurant
# 8          Venue Category_Seafood Restaurant
# 9          Venue Category_Italian Restaurant
# 11              Venue Category_Grocery Store
# 14                       Venue Category_Café
# 15                        Venue Category_Gym
# 16                        Venue Category_Pub
#
#                  7th Most Common Venue  \
# 0               Venue Category_Theater
# 1   Venue Category_Japanese Restaurant
# 2                   Venue Category_Gym
# 3            Venue Category_Restaurant
# 4       Venue Category_Bubble Tea Shop
# 6        Venue Category_Clothing Store
# 7        Venue Category_Scenic Lookout
# 8   Venue Category_Japanese Restaurant
# 9   Venue Category_American Restaurant
# 11         Venue Category_Dessert Shop
# 14         Venue Category_Gourmet Shop
# 15     Venue Category_Asian Restaurant
# 16          Venue Category_Men's Store
#
#                       8th Most Common Venue  \
# 0         Venue Category_Mexican Restaurant
# 1       Venue Category_Fast Food Restaurant
# 2             Venue Category_Farmers Market
# 3         Venue Category_Seafood Restaurant
# 4               Venue Category_Burger Joint
# 6                        Venue Category_Gym
# 7                    Venue Category_Brewery
# 8         Venue Category_Italian Restaurant
# 9         Venue Category_Seafood Restaurant
# 11            Venue Category_Farmers Market
# 14               Venue Category_Pizza Place
# 15        Venue Category_Seafood Restaurant
# 16  Venue Category_Mediterranean Restaurant
#
#                  9th Most Common Venue  \
# 0            Venue Category_Restaurant
# 1             Venue Category_Bookstore
# 2   Venue Category_Moroccan Restaurant
# 3              Venue Category_Beer Bar
# 4   Venue Category_Japanese Restaurant
# 6           Venue Category_Pizza Place
# 7            Venue Category_Restaurant
# 8   Venue Category_Sporting Goods Shop
# 9          Venue Category_Cocktail Bar
# 11                 Venue Category_Park
# 14    Venue Category_Indian Restaurant
# 15          Venue Category_Salad Place
# 16                Venue Category_Hotel
#
#                        10th Most Common Venue
# 0               Venue Category_Chocolate Shop
# 1             Venue Category_Ramen Restaurant
# 2             Venue Category_Department Store
# 3              Venue Category_Thai Restaurant
# 4   Venue Category_Modern European Restaurant
# 6                 Venue Category_Concert Hall
# 7          Venue Category_Fried Chicken Joint
# 8             Venue Category_Sushi Restaurant
# 9          Venue Category_Japanese Restaurant
# 11                         Venue Category_Bar
# 14                        Venue Category_Park
# 15               Venue Category_Deli / Bodega
# 16                     Venue Category_Gay Bar

# %%
downtown_merged.loc[downtown_merged['Cluster Labels'] == 1, 
                    downtown_merged.columns[[1] + list(range(5, downtown_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 13  Downtown Toronto               1   Venue Category_Park
#
#         2nd Most Common Venue 3rd Most Common Venue  \
# 13  Venue Category_Playground  Venue Category_Trail
#
#           4th Most Common Venue               5th Most Common Venue  \
# 13  Venue Category_Dance Studio  Venue Category_Dumpling Restaurant
#
#         6th Most Common Venue            7th Most Common Venue  \
# 13  Venue Category_Donut Shop  Venue Category_Doner Restaurant
#
#      8th Most Common Venue               9th Most Common Venue  \
# 13  Venue Category_Dog Run  Venue Category_Distribution Center
#
#            10th Most Common Venue
# 13  Venue Category_Discount Store

# %%
downtown_merged.loc[downtown_merged['Cluster Labels'] == 2, 
                    downtown_merged.columns[[1] + list(range(5, downtown_merged.shape[1]))]]
# Out:
#             Borough  Cluster Labels         1st Most Common Venue  \
# 5  Downtown Toronto               2  Venue Category_Grocery Store
#
#   2nd Most Common Venue 3rd Most Common Venue       4th Most Common Venue  \
# 5   Venue Category_Café   Venue Category_Park  Venue Category_Candy Store
#
#                5th Most Common Venue              6th Most Common Venue  \
# 5  Venue Category_Italian Restaurant  Venue Category_Athletics & Sports
#
#        7th Most Common Venue      8th Most Common Venue  \
# 5  Venue Category_Restaurant  Venue Category_Baby Store
#
#       9th Most Common Venue      10th Most Common Venue
# 5  Venue Category_Nightclub  Venue Category_Coffee Shop

# %%
downtown_merged.loc[downtown_merged['Cluster Labels'] ==3, 
                    downtown_merged.columns[[1] + list(range(5, downtown_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels          1st Most Common Venue  \
# 12  Downtown Toronto               3  Venue Category_Airport Lounge
#
#               2nd Most Common Venue 3rd Most Common Venue  \
# 12  Venue Category_Airport Terminal  Venue Category_Plane
#
#              4th Most Common Venue            5th Most Common Venue  \
# 12  Venue Category_Harbor / Marina  Venue Category_Sculpture Garden
#
#            6th Most Common Venue               7th Most Common Venue  \
# 12  Venue Category_Boat or Ferry  Venue Category_Rental Car Location
#
#    8th Most Common Venue       9th Most Common Venue   10th Most Common Venue
# 12    Venue Category_Bar  Venue Category_Coffee Shop  Venue Category_Boutique

# %%
downtown_merged.loc[downtown_merged['Cluster Labels'] == 4, 
                    downtown_merged.columns[[1] + list(range(5, downtown_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 10  Downtown Toronto               4   Venue Category_Café
#
#        2nd Most Common Venue 3rd Most Common Venue  \
# 10  Venue Category_Bookstore    Venue Category_Bar
#
#                 4th Most Common Venue               5th Most Common Venue  \
# 10  Venue Category_Italian Restaurant  Venue Category_Japanese Restaurant
#
#     6th Most Common Venue       7th Most Common Venue  \
# 10  Venue Category_Bakery  Venue Category_Yoga Studio
#
#       8th Most Common Venue                   9th Most Common Venue  \
# 10  Venue Category_Beer Bar  Venue Category_Comfort Food Restaurant
#
#            10th Most Common Venue
# 10  Venue Category_Sandwich Place
